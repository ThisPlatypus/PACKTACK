# %% [markdown]
# # Download data

# %%
import pandas as pd
dataset_name=['CTU-IoT-Malware-Capture-52-1','CTU-IoT-Malware-Capture-20-1','CTU-IoT-Malware-Capture-21-1','CTU-IoT-Malware-Capture-42-1','CTU-IoT-Malware-Capture-60-1','CTU-IoT-Malware-Capture-17-1','CTU-IoT-Malware-Capture-36-1','CTU-IoT-Malware-Capture-33-1','CTU-IoT-Malware-Capture-8-1','CTU-IoT-Malware-Capture-35-1','CTU-IoT-Malware-Capture-48-1','CTU-IoT-Malware-Capture-39-1','CTU-IoT-Malware-Capture-7-1','CTU-IoT-Malware-Capture-9-1','CTU-IoT-Malware-Capture-3-1','CTU-IoT-Malware-Capture-1-1', 'CTU-IoT-Malware-Capture-34-1','CTU-IoT-Malware-Capture-43-1', 'CTU-IoT-Malware-Capture-44-1','CTU-IoT-Malware-Capture-49-1']

# %%
import requests
remote_url = 'https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-43-1/labeled/conn.log.labeled'
local_file = f'C:\\Users\\chiar\\PycharmProjects\\PACKTACK\\Data\\CTU-IoT-Malware-Capture-43-1.txt'
data = requests.get(remote_url)
with open(local_file, 'wb')as file:
       file.write(data.content)

# %%
import requests
for name in dataset_name:
    if name=='CTU-IoT-Malware-Capture-43-1':
     remote_url = 'https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-43-1/labeled/conn.log.labeled'
    else:
        # Define the remote file to retrieve
        remote_url = f'https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/{name}/bro/conn.log.labeled'
    # Define the local filename to save data
    local_file = f'C:\\Users\\chiar\\PycharmProjects\\PACKTACK\\Data\\{name}.txt'
    # Make http request for remote file data
    data = requests.get(remote_url)
    # Save file data to local copy
    with open(local_file, 'wb')as file:
        file.write(data.content)

# %% [markdown]
# # Clean data - with R
# # Reload data cleaned
# # Cancellare quelli di durata 0? - puoi farlo direttamente su R
# # Quali altri  cancellare????

# %%
#Load Data
X = pd.read_csv("C:\\Users\\chiar\\PycharmProjects\\PACKTACK\\Data\\CleanData\\CTU-IoT-Malware-Capture-44-1.txt", sep="\t", header=0)

#Replace NaN from duration
X['duration'] = X['duration'] .fillna(0)

# Display data
X
# Out:
#                ts                 uid      id.orig_h  id.orig_p  \
# 0    1.547151e+09  CzsY0D4B96NTr8m7ld  192.168.1.199      59222
# 1    1.547151e+09  CGEJbl3RNkmXzmkEd4  192.168.1.199      59224
# 2    1.547151e+09   CVMYDw4wnZfqWrOfd  192.168.1.199      59224
# 3    1.547151e+09   CXKZmpx40udvITEN2  192.168.1.199      59224
# 4    1.547151e+09   CBjcNy4pOh8Xg1H4S  192.168.1.199      59224
# ..            ...                 ...            ...        ...
# 232  1.547157e+09  CJrY2v1tAQ2wSbAkw8  192.168.1.199        123
# 233  1.547151e+09  CciS4F261blHGCR5xa  192.168.1.199      51834
# 234  1.547158e+09  CVhlni1vUjmHbv2XYg  192.168.1.199        123
# 235  1.547158e+09  ChNxXQ3tFSWXUDDMVa  192.168.1.199        123
# 236  1.547158e+09  Cl719X2VltGmT4khp4  192.168.1.199        123
#
#           id.resp_h  id.resp_p proto service     duration orig_bytes  ...  \
# 0    46.101.251.172         80   tcp    http     1.686784        149  ...
# ...

# %%
# Summary of data
X.describe()
# Out:
#                  ts     id.orig_p   id.resp_p     duration  missed_bytes  \
# count  2.370000e+02    237.000000  237.000000   156.000000    237.000000
# mean   1.547153e+09   6813.662447  117.189873    46.958475    439.898734
# std    1.901582e+03  18452.240493   17.052568   545.162848   2366.063854
# min    1.547151e+09    123.000000   22.000000     0.001982      0.000000
# 25%    1.547152e+09    123.000000  123.000000     0.005480      0.000000
# 50%    1.547153e+09    123.000000  123.000000     0.012485      0.000000
# 75%    1.547154e+09    123.000000  123.000000     0.100758      0.000000
# max    1.547158e+09  59244.000000  123.000000  6803.476778  20272.000000
#
#           orig_pkts  orig_ip_bytes   resp_pkts  resp_ip_bytes
# count  2.370000e+02   2.370000e+02  237.000000     237.000000
# mean   5.514646e+03   7.516844e+06    7.966245    7378.624473
# std    8.477054e+04   1.157125e+08   34.683785   32378.914359
# min    1.000000e+00   6.000000e+01    0.000000       0.000000
# ...

# %%
# Summary of data by label
X.groupby("label").mean(numeric_only=True)
# Out:
#                      ts     id.orig_p   id.resp_p    duration  missed_bytes  \
# label
# Benign     1.547153e+09    485.890995  122.042654    1.372826      0.000000
# Malicious  1.547151e+09  58165.961538   77.807692  419.688191   4009.846154
#
#               orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes
# label
# Benign         2.222749   1.447014e+02   1.777251     253.554502
# Malicious  50250.076923   6.851775e+07  58.192308   65201.307692

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
X['duration'].plot()

plt.show()

# %%
X['missed_bytes'].plot()

# %%
X['orig_pkts'].plot()
# Out:
# <Axes: >

# %%
X['resp_pkts'].plot()
X['orig_pkts'].plot()
plt.show()

# %%
X['orig_ip_bytes'].plot()
# Out:
# <Axes: >

# %%
X['resp_ip_bytes'].plot()

plt.show()

# %% [markdown]
# # Utillities

# %%
X.duration = list(map(lambda x: x.replace('-', '0'), X.duration))

X['duration']=pd.to_numeric(X['duration'],errors='coerce')
